# %% [markdown]
# DATA EXPLORATION - VANGUARD A/B TEST

# %% [markdown]
# IMPORT LIBRARIES

# %%
import pandas as pd 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set_style("whitegrid")

# %% [markdown]
# 1. LOAD THE DATASETS

# %%
data_path = "data/raw_data"
df_demo = pd.read_csv(f"{data_path}/df_final_demo.txt")
df_experiment = pd.read_csv(f"{data_path}/df_final_experiment_clients.txt")
df_web_1 = pd.read_csv(f"{data_path}/df_final_web_data_pt_1.txt")
df_web_2 = pd.read_csv(f"{data_path}/df_final_web_data_pt_2.txt")

web = pd.concat([df_web_1, df_web_2], axis=0)

# %%
df_demo.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1    2304905             7.0              94.0      58.0     U        2.0
# 2    1439522             5.0              64.0      32.0     U        2.0
# 3    1562045            16.0             198.0      49.0     M        2.0
# 4    5126305            12.0             145.0      33.0     F        2.0
#
#          bal  calls_6_mnth  logons_6_mnth
# 0   45105.30           6.0            9.0
# 1  110860.30           6.0            9.0
# 2   52467.79           6.0            9.0
# 3   67454.65           3.0            6.0
# 4  103671.75           0.0            3.0

# %%
df_demo.isnull().sum()
# Out:
# client_id            0
# clnt_tenure_yr      14
# clnt_tenure_mnth    14
# clnt_age            15
# gendr               14
# num_accts           14
# bal                 14
# calls_6_mnth        14
# logons_6_mnth       14
# dtype: int64

# %%
df_experiment.head()
# Out:
#    client_id Variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control
# 3    1982004      Test
# 4    9294070   Control

# %%
df_experiment.shape
# Out:
# (70609, 2)

# %%
#In this dataset, there are 20109 missing values, which means this customers need to be dropped out, since they didn't make into the sample
df_experiment.isnull().sum()
df_experiment.nunique()

#Check unique values in the Vatiation column
df_experiment["Variation"].unique()
# Out:
# array(['Test', 'Control', nan], dtype=object)

# %%
df_web_1.head()
df_web_1.shape
# Out:
# (343141, 5)

# %%
df_web_2.head()
df_web_2.shape
# Out:
# (412264, 5)

# %%
web.isnull().sum()
# Out:
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64

# %%
web.head(10)
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 5    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 6    9988021  580560515_7732621733  781255054_21935453173_531117       step_1
# 7    9988021  580560515_7732621733  781255054_21935453173_531117        start
# 8    8320017  39393514_33118319366  960651974_70596002104_312201      confirm
# 9    8320017  39393514_33118319366  960651974_70596002104_312201       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# ...
